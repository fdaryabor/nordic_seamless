# %%
from netCDF4 import Dataset
myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)

ax.set_xticks(np.arange(start=4.32000e+05, stop=3.15360e+08+1, step=31492800.0))
ax.set_xticklabels(labels)
ax.set_ylim([-1000,0])
ax.set_xlabel('Year')
ax.set_ylabel('dept (m)')
ax.set_title('Potential Temperature')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2ff9bd4b4f44> in <module>()
#       2 myfile = 'result.nc'
#       3 fh = Dataset(myfile, mode = 'r')
# ----> 4 time  = np.transpose(np.squeeze(fh.variables['time'][:]))
#       5 dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
#       6 temp  = np.transpose(np.squeeze(fh.variables['temp'][:]))
#
# NameError: name 'np' is not defined

# %%
myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)

ax.set_xticks(np.arange(start=4.32000e+05, stop=3.15360e+08+1, step=31492800.0))
ax.set_xticklabels(labels)
ax.set_ylim([-1000,0])
ax.set_xlabel('Year')
ax.set_ylabel('dept (m)')
ax.set_title('Potential Temperature')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c8cd80693c21> in <module>()
#       1 myfile = 'result.nc'
#       2 fh = Dataset(myfile, mode = 'r')
# ----> 3 time  = np.transpose(np.squeeze(fh.variables['time'][:]))
#       4 dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
#       5 temp  = np.transpose(np.squeeze(fh.variables['temp'][:]))
#
# NameError: name 'np' is not defined

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime



myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)

ax.set_xticks(np.arange(start=4.32000e+05, stop=3.15360e+08+1, step=31492800.0))
ax.set_xticklabels(labels)
ax.set_ylim([-1000,0])
ax.set_xlabel('Year')
ax.set_ylabel('dept (m)')
ax.set_title('Potential Temperature')

plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-68d4cbb077f1> in <module>()
#      37
#      38 ax.set_xticks(np.arange(start=4.32000e+05, stop=3.15360e+08+1, step=31492800.0))
# ---> 39 ax.set_xticklabels(labels)
#      40 ax.set_ylim([-1000,0])
#      41 ax.set_xlabel('Year')
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1788         if fontdict is not None:
#    1789             kwargs.update(fontdict)
# -> 1790         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1791
#    1792     def set_ticks(self, ticks, *, minor=False):
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1710             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
#    1711                 raise ValueError(
# -> 1712                     "The number of FixedLocator locations"
#    1713                     f" ({len(locator.locs)}), usually from a call to"
#    1714                     " set_ticks, does not match"
#
# ValueError: The number of FixedLocator locations (11), usually from a call to set_ticks, does not match the number of ticklabels (10).

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime



myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime



myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()



def out_date_by_day(day):
    first_day=datetime.datetime(2010,1,1)
    add_day=datetime.timedelta(days=day)
    return datetime.datetime.strftime(first_day+add_day,"%Y.%m.%d")

dates=[]
for t in Time:
       dates.append(out_date_by_day(t)

#years = range(2010, 2020)
#labels = []
#for st in years:
#    label = str(st)
#    labels.append(label)

#plt.rcParams["figure.figsize"] = (12,5) 
#plt.rcParams.update({'font.size': 18})

fig = plt.figure(1)
                    
#fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
                    
ax.set_xticklabels(dates)  

 plt.show()
# Out:
#   File "<ipython-input-5-e392ce74360c>", line 40
#     fig = plt.figure(1)
#       ^
# SyntaxError: invalid syntax

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime



myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()



def out_date_by_day(day):
    first_day=datetime.datetime(2010,1,1)
    add_day=datetime.timedelta(days=day)
    return datetime.datetime.strftime(first_day+add_day,"%Y.%m.%d")

dates=[]
for t in Time:
       dates.append(out_date_by_day(t)

#years = range(2010, 2020)
#labels = []
#for st in years:
#    label = str(st)
#    labels.append(label)

#plt.rcParams["figure.figsize"] = (12,5) 
#plt.rcParams.update({'font.size': 18})

fig = plt.figure()
                    
fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
                    
ax.set_xticklabels(dates)  

 plt.show()
# Out:
#   File "<ipython-input-6-fa29d0e970fd>", line 40
#     fig = plt.figure(1)
#       ^
# SyntaxError: invalid syntax

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime



myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()



def out_date_by_day(day):
    first_day=datetime.datetime(2010,1,1)
    add_day=datetime.timedelta(days=day)
    return datetime.datetime.strftime(first_day+add_day,"%Y.%m.%d")

dates=[]
for t in Time:
       dates.append(out_date_by_day(t)

#years = range(2010, 2020)
#labels = []
#for st in years:
#    label = str(st)
#    labels.append(label)

#plt.rcParams["figure.figsize"] = (12,5) 
#plt.rcParams.update({'font.size': 18})

#fig = plt.figure()
                    
#fig, ax = plt.subplots()

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
                    
ax.set_xticklabels(dates)  

 plt.show()
# Out:
#   File "<ipython-input-10-e6bd1f4db597>", line 44
#     pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')
#              ^
# SyntaxError: invalid syntax

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
ax.set_xticklabels(labels)
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
ax.set_xticklabels(labels)
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if sys.path[0] == '':
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
ax.set_xticks(np.arange(start=2010, stop=2020, step=1))
ax.set_xticklabels(labels)
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if sys.path[0] == '':
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
ax.set_xticks(np.arange(start=0, stop=347068800+1, step=86400))
ax.set_xticklabels(labels)
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if sys.path[0] == '':
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-0d286ac88d6e> in <module>()
#      33 cb.set_label(label='degree Celsius')
#      34 pcolorplot.set_clim(10, 25)
# ---> 35 ax.set_xticks(np.arange(min(labels), max(labels)+1, 1.0))
#      36 ax.set_xticklabels(labels)
#      37 plt.show()
#
# TypeError: can only concatenate str (not "int") to str

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
ax.set_xticks(np.arange(start=86400, stop=347068800+1, step=86400))
ax.set_xticklabels(labels)
plt.show()

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
#ax.set_xticks(np.arange(start=86400, stop=347068800+1, step=86400))
ax.set_xticklabels(labels)
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if sys.path[0] == '':
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
#ax.set_xticks(np.arange(start=2010, stop=2020+1, step=2020))
ax.set_xticklabels(labels-1)
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if sys.path[0] == '':
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-904dd89522ba> in <module>()
#      34 pcolorplot.set_clim(10, 25)
#      35 ax.set_xticks(np.arange(start=2010, stop=2020+1, step=2020))
# ---> 36 ax.set_xticklabels(labels)
#      37 plt.show()
#      38
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1788         if fontdict is not None:
#    1789             kwargs.update(fontdict)
# -> 1790         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1791
#    1792     def set_ticks(self, ticks, *, minor=False):
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1710             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
#    1711                 raise ValueError(
# -> 1712                     "The number of FixedLocator locations"
#    1713                     f" ({len(locator.locs)}), usually from a call to"
#    1714                     " set_ticks, does not match"
#
# ValueError: The number of FixedLocator locations (1), usually from a call to set_ticks, does not match the number of ticklabels (10).

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
#ax.set_xticks(np.arange(start=2010, stop=2020+1, step=2020))
ax.set_xticklabels(labels-1)
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if sys.path[0] == '':
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-5b1950925f3e> in <module>()
#      34 pcolorplot.set_clim(10, 25)
#      35 #ax.set_xticks(np.arange(start=2010, stop=2020+1, step=2020))
# ---> 36 ax.set_xticklabels(labels-1)
#      37 plt.show()
#      38
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime
import matplotlib.dates as mdates

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
#ax.set_xticks(np.arange(start=2010, stop=2020+1, step=2020))
ax.set_xticklabels(labels)
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime
import matplotlib.dates as mdates

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
#ax.set_xticks(np.arange(start=2010, stop=2020+1, step=2020))
ax.set_xticklabels(labels)
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime
import matplotlib.dates as mdates

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)
    
print(labels)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
#ax.set_xticks(np.arange(start=2010, stop=2020+1, step=2020))
ax.set_xticklabels(labels)
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime
import matplotlib.dates as mdates

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)
    
print(labels)

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
ax.set_xticklabels(labels)
xticks = pd.date_range(datetime.datetime(2010,1,1), datetime.datetime(2019,1,1), freq='YS')

plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: FixedFormatter should only be used together with FixedLocator
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime
import matplotlib.dates as mdates

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)
    
print(labels)
print(min(labels))
print(max(labels))

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
ax.set_xticks(np.arange(start=0, stop= 34706800  , step=31536000.0))
ax.set_xticklabels(labels)
#plt.xticks(rotation=90);
plt.show()
# Out:
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
# 2010
# 2019
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-943d1c76b35c> in <module>()
#      39 pcolorplot.set_clim(10, 25)
#      40 ax.set_xticks(np.arange(start=0, stop= 34706800  , step=31536000.0))
# ---> 41 ax.set_xticklabels(labels)
#      42 #plt.xticks(rotation=90);
#      43 plt.show()
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1788         if fontdict is not None:
#    1789             kwargs.update(fontdict)
# -> 1790         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1791
#    1792     def set_ticks(self, ticks, *, minor=False):
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1710             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
#    1711                 raise ValueError(
# -> 1712                     "The number of FixedLocator locations"
#    1713                     f" ({len(locator.locs)}), usually from a call to"
#    1714                     " set_ticks, does not match"
#
# ValueError: The number of FixedLocator locations (2), usually from a call to set_ticks, does not match the number of ticklabels (10).

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime
import matplotlib.dates as mdates

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)
    
print(labels)
print(min(labels))
print(max(labels))

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
ax.set_xticks = pd.date_range(datetime.datetime(2010,1,1), datetime.datetime(2019,1,1), freq='YS')
ax.set_xticklabels(labels)
#plt.xticks(rotation=90);
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:41: UserWarning: FixedFormatter should only be used together with FixedLocator
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
# 2010
# 2019

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime
import matplotlib.dates as mdates

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2020)
labels = []
for st in years:
    label = str(st)
    labels.append(label)
    
print(labels)
print(min(labels))
print(max(labels))

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
ax.set_xticks(np.arange(start=0, stop= 34706800+500  , step=360*24*3600))
ax.set_xticklabels(labels)
#plt.xticks(rotation=90);
plt.show()
# Out:
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
# 2010
# 2019
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-743abdaf0bab> in <module>()
#      39 pcolorplot.set_clim(10, 25)
#      40 ax.set_xticks(np.arange(start=0, stop= 34706800+500  , step=360*24*3600))
# ---> 41 ax.set_xticklabels(labels)
#      42 #plt.xticks(rotation=90);
#      43 plt.show()
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1788         if fontdict is not None:
#    1789             kwargs.update(fontdict)
# -> 1790         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1791
#    1792     def set_ticks(self, ticks, *, minor=False):
#
# /home/ollie/fdaryabo/.local/lib/python3.7/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1710             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
#    1711                 raise ValueError(
# -> 1712                     "The number of FixedLocator locations"
#    1713                     f" ({len(locator.locs)}), usually from a call to"
#    1714                     " set_ticks, does not match"
#
# ValueError: The number of FixedLocator locations (2), usually from a call to set_ticks, does not match the number of ticklabels (10).

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime
import matplotlib.dates as mdates

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))
fh.close()

years = range(2010, 2022)
labels = []
for st in years:
    label = str(st)
    labels.append(label)
    
print(labels)
print(min(labels))
print(max(labels))

plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, temp, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)
cb.set_label(label='degree Celsius')
pcolorplot.set_clim(10, 25)
ax.set_xticks(np.arange(start=0, stop= 347068800+5  , step=31551709.09))
ax.set_xticklabels(labels)
#plt.xticks(rotation=90);
ax.set_xlabel('Year')
ax.set_ylabel('Depth (m)')
ax.set_title('Potential Temperature')
#fig.savefig('/Users/farshidlocal/Desktop/Arkona-case-2010-2020')
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
# 2010
# 2021

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import datetime
import matplotlib.dates as mdates

myfile = 'result.nc'
fh = Dataset(myfile, mode = 'r')
time  = np.transpose(np.squeeze(fh.variables['time'][:]))
dept  = np.transpose(np.squeeze(fh.variables['z'][:]))
temp  = np.transpose(np.squeeze(fh.variables['temp'][:])) 
salt  = np.transpose(np.squeeze(fh.variables['salt'][:]))

oxyg  = np.transpose(np.squeeze(fh.variables['ergom_oxy'][:]))
phos  = np.transpose(np.squeeze(fh.variables['ergom_pho'][:]))
zoop  = np.transpose(np.squeeze(fh.variables['ergom_zoo'][:]))

nitr  = np.transpose(np.squeeze(fh.variables['ergom_nit'][:]))
cyan  = np.transpose(np.squeeze(fh.variables['ergom_cya'][:]))

fh.close()

years = range(2010, 2022)
labels = []
for st in years:
    label = str(st)
    labels.append(label)
    
plt.rcParams["figure.figsize"] = (12,5) 
plt.rcParams.update({'font.size': 18})


fig, ax = plt.subplots(constrained_layout=True)

pcolorplot = ax.pcolormesh(time, dept, cyan, cmap='RdBu_r', shading='auto')

cb = plt.colorbar(pcolorplot, orientation="vertical", pad=0.01)

#cb.set_label(label='degree Celsius')
#cb.set_label(label='gr/kg')
cb.set_label(label='mmol N/m3')

#pcolorplot.set_clim(10, 25)
ax.set_xticks(np.arange(start=0, stop= 347068800+5  , step=31551709.09))
ax.set_xticklabels(labels)
#plt.xticks(rotation=90);
ax.set_xlabel('Year')
ax.set_ylabel('Depth (m)')
ax.set_title('ERGOM-cyanobacteria')
#fig.savefig('/Users/farshidlocal/Desktop/Arkona-case-2010-2020')
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:19: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:22: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:23: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
import netCDF4
from netCDF4 import Dataset
import numpy as np 
import tkinter,datetime
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.dates as dates

def out_date_by_day(second):
    first_s=datetime.datetime(2010,1,1)
    add_s=datetime.timedelta(seconds=second)
    return datetime.datetime.strftime(first_s+add_s,"%Y-%m-%d %H:%M:%S")


myfile = r'result.nc'

fh = Dataset(myfile, mode = 'r')

Time= fh.variables['time'][:]
H= fh.variables['h'][:]
Z= fh.variables['z'][:]
Zi= fh.variables['zi'][:]

tt= fh.variables['temp'][:]
ss= fh.variables['salt'][:]

ox= fh.variables['ergom_oxy'][:]
ph= fh.variables['ergom_pho'][:]
zo= fh.variables['ergom_zoo'][:]
ni= fh.variables['ergom_nit'][:]
cy= fh.variables['ergom_cya'][:]
fh.close()
#
date=[]
for t in Time:
	date.append(out_date_by_day(t))
date_after = [val for val in date for i in range(ss.shape[1])]
date_after = pd.to_datetime(date_after)

# Sequences
fig = plt.figure()
ax1 = fig.add_subplot(111)
fig.autofmt_xdate()
xfmt = dates.DateFormatter('%d-%m-%y')
ax1.xaxis.set_major_formatter(xfmt)

# Plot first var, and set tick labels to the same color
ax1.plot(date_after,np.squeeze(tt[:,:]).flatten(), color='red',alpha = 0.5)
ax1.tick_params(axis='y', labelcolor='red')
ax1.set_ylabel('potential temperature-(degree Celsius)')

# Generate a new Axes instance, on the twin-X axes (same position)
ax2 = ax1.twinx()
# Plot second var, set scale to logarithmic and change tick color
ax2.plot(date_after,np.squeeze(ss[:,:]).flatten(), color='green',alpha = 0.5)
ax2.tick_params(axis='y', labelcolor='green')
ax2.set_ylabel('sea water practical salinity-(g/kg)')
plt.show()



fig = plt.figure()
ax1 = fig.add_subplot(111)
fig.autofmt_xdate()
xfmt = dates.DateFormatter('%d-%m-%y')
ax1.xaxis.set_major_formatter(xfmt)

# Plot first var, and set tick labels to the same color
ax1.plot(date_after,np.squeeze(ox[:,:]).flatten(), color='red',alpha = 0.5)
ax1.tick_params(axis='y', labelcolor='red')
ax1.set_ylabel('ERGOM-oxygen-(mmol O2/m3)')

# Generate a new Axes instance, on the twin-X axes (same position)
ax2 = ax1.twinx()
# Plot second var, set scale to logarithmic and change tick color
ax2.plot(date_after,np.squeeze(zo[:,:]).flatten(), color='green',alpha = 0.5)
ax2.tick_params(axis='y', labelcolor='green')
ax2.set_ylabel('ERGOM-zooplankton-(mmol N/m3)')
plt.show()


fig = plt.figure()
ax1 = fig.add_subplot(111)
fig.autofmt_xdate()
xfmt = dates.DateFormatter('%d-%m-%y')
ax1.xaxis.set_major_formatter(xfmt)

# Plot first var, and set tick labels to the same color
ax1.plot(date_after,np.squeeze(ni[:,:]).flatten(), color='red',alpha = 0.5)
ax1.tick_params(axis='y', labelcolor='red')
ax1.set_ylabel('ERGOM-nitrate-(mmol N/m3)')

# Generate a new Axes instance, on the twin-X axes (same position)
ax2 = ax1.twinx()
# Plot second var, set scale to logarithmic and change tick color
ax2.plot(date_after,np.squeeze(cy[:,:]).flatten(), color='green',alpha = 0.5)
ax2.tick_params(axis='y', labelcolor='green')
ax2.set_ylabel('ERGOM-cyanobacteria-(mmol N/m3)')
plt.show()
# Out:
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:19: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:22: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:25: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:27: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:29: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:30: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /global/AWIsoft/intel-python/2020.2.902/lib/python3.7/site-packages/ipykernel_launcher.py:31: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
